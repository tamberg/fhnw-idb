# %% [markdown]
# # Example of a Jupyter Notebook

# %% [markdown]
# ## Import CSV File

# %%
import pandas as pd
data = pd.read_csv("./dht.csv")
data.head()
# Out:
#        Time  Temp  Hum
# 0  12:35:00    27   52
# 1  12:35:15    27   51
# 2  12:35:30    27   51
# 3  12:35:45    27   52
# 4  12:36:00    28   69

# %% [markdown]
# ## Plot Data

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

time = data['Time']
plt.plot(data['Time'], data['Temp'], '-b', label='Temp')
plt.plot(data['Time'], data['Hum'], '-r', label='Hum')

axs = plt.axes()
axs.xaxis.set_major_locator(ticker.MultipleLocator(10))

plt.legend()
